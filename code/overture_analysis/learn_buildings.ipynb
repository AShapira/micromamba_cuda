# %% [markdown]
# # Inspect Overture buildings GeoParquet files
#
# This notebook targets the `theme=buildings/type=building` release folder, reports schema details, and previews a few rows from the GeoParquet files using DuckDB. All files share the same structure, so a single sample per directory is sufficient.

# %%
from pathlib import Path
from collections import defaultdict

import duckdb
from IPython.display import display

repo_root = Path.cwd().resolve().parents[1]
base_path = repo_root / 'gis_data' / 'overturemaps-us-west-2' / 'release' / '2025-08-20.1' / 'theme=buildings' / 'type=building'
print(f'Base directory: {base_path}')

parquet_files = sorted(base_path.rglob('*.parquet'))
if not parquet_files:
    raise FileNotFoundError('No GeoParquet files found in theme=buildings/type=building.')

files_by_dir = defaultdict(list)
for file_path in parquet_files:
    files_by_dir[file_path.parent].append(file_path)

print(f'Found {len(parquet_files)} parquet files across {len(files_by_dir)} directories.')
for directory, files in sorted(files_by_dir.items()):
    rel_dir = directory.relative_to(base_path)
    print(f'{rel_dir}: {len(files)} file(s)')
# Out:
# Base directory: /workspace/gis_data/overturemaps-us-west-2/release/2025-08-20.1/theme=buildings/type=building
# Found 237 parquet files across 1 directories.
# .: 237 file(s)

# %%
import json
from pyarrow import parquet as pq

sample_file_for_metadata = parquet_files[0]
print(f"Inspecting metadata for: {sample_file_for_metadata.name}")
pq_file = pq.ParquetFile(sample_file_for_metadata)
key_value_metadata = pq_file.metadata.metadata or {}

def _decode_if_bytes(value):
    return value.decode('utf-8', 'replace') if isinstance(value, (bytes, bytearray)) else value

decoded_metadata = {
    _decode_if_bytes(k): _decode_if_bytes(v)
    for k, v in key_value_metadata.items()
}
print(json.dumps(decoded_metadata, indent=2))

geo_metadata = decoded_metadata.get('geo')
if geo_metadata:
    try:
        geo_json = json.loads(geo_metadata)
        primary_column = geo_json.get('primary_column')
        columns = geo_json.get('columns', {})
        geometry_info = columns.get(primary_column, {}) if columns else {}
        bbox = geometry_info.get('bbox')
        if bbox:
            print('Geometry bounding box:', bbox)
    except json.JSONDecodeError:
        print('Unable to parse geo metadata as JSON.')
# Out:
# Inspecting metadata for: part-00000-c8f91a12-b93f-4285-9103-a7779634c4ce-c000.zstd.parquet
# {
#   "org.apache.spark.sql.parquet.row.metadata": "{\"type\":\"struct\",\"fields\":[{\"name\":\"id\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"geometry\",\"type\":\"binary\",\"nullable\":true,\"metadata\":{}},{\"name\":\"bbox\",\"type\":{\"type\":\"struct\",\"fields\":[{\"name\":\"xmin\",\"type\":\"float\",\"nullable\":true,\"metadata\":{}},{\"name\":\"xmax\",\"type\":\"float\",\"nullable\":true,\"metadata\":{}},{\"name\":\"ymin\",\"type\":\"float\",\"nullable\":true,\"metadata\":{}},{\"name\":\"ymax\",\"type\":\"float\",\"nullable\":true,\"metadata\":{}}]},\"nullable\":true,\"metadata\":{}},{\"name\":\"version\",\"type\":\"integer\",\"nullable\":true,\"metadata\":{}},{\"name\":\"sources\",\"type\":{\"type\":\"array\",\"elementType\":{\"type\":\"struct\",\"fields\":[{\"name\":\"property\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"dataset\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"record_id\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"update_time\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"confidence\",\"type\":\"double\",\"nullable\":true,\"metadata\":{}},{\"name\":\"between\",\"type\":{\"type\":\"array\",\"elementType\":\"double\",\"containsNull\":true},\"nullable\":true,\"metadata\":{}}]},\"containsNull\":true},\"nullable\":true,\"metadata\":{}},{\"name\":\"level\",\"type\":\"integer\",\"nullable\":true,\"metadata\":{}},{\"name\":\"subtype\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"class\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"height\",\"type\":\"double\",\"nullable\":true,\"metadata\":{}},{\"name\":\"names\",\"type\":{\"type\":\"struct\",\"fields\":[{\"name\":\"primary\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"common\",\"type\":{\"type\":\"map\",\"keyType\":\"string\",\"valueType\":\"string\",\"valueContainsNull\":true},\"nullable\":true,\"metadata\":{}},{\"name\":\"rules\",\"type\":{\"type\":\"array\",\"elementType\":{\"type\":\"struct\",\"fields\":[{\"name\":\"variant\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"language\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"perspectives\",\"type\":{\"type\":\"struct\",\"fields\":[{\"name\":\"mode\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"countries\",\"type\":{\"type\":\"array\",\"elementType\":\"string\",\"containsNull\":true},\"nullable\":true,\"metadata\":{}}]},\"nullable\":true,\"metadata\":{}},{\"name\":\"value\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"between\",\"type\":{\"type\":\"array\",\"elementType\":\"double\",\"containsNull\":true},\"nullable\":true,\"metadata\":{}},{\"name\":\"side\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}}]},\"containsNull\":true},\"nullable\":true,\"metadata\":{}}]},\"nullable\":true,\"metadata\":{}},{\"name\":\"has_parts\",\"type\":\"boolean\",\"nullable\":true,\"metadata\":{}},{\"name\":\"is_underground\",\"type\":\"boolean\",\"nullable\":true,\"metadata\":{}},{\"name\":\"num_floors\",\"type\":\"integer\",\"nullable\":true,\"metadata\":{}},{\"name\":\"num_floors_underground\",\"type\":\"integer\",\"nullable\":true,\"metadata\":{}},{\"name\":\"min_height\",\"type\":\"double\",\"nullable\":true,\"metadata\":{}},{\"name\":\"min_floor\",\"type\":\"integer\",\"nullable\":true,\"metadata\":{}},{\"name\":\"facade_color\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"facade_material\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"roof_material\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"roof_shape\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"roof_direction\",\"type\":\"double\",\"nullable\":true,\"metadata\":{}},{\"name\":\"roof_orientation\",\"type\":\"string\",\"nullable\":true,\"metadata\":{}},{\"name\":\"roof_color\",\"type\":\"string\",\"nullable\ ...
#   "geo": "{\"version\":\"1.1.0\",\"primary_column\":\"geometry\",\"columns\":{\"geometry\":{\"encoding\":\"WKB\",\"geometry_types\":[\"Polygon\",\"MultiPolygon\"],\"bbox\":[-179.9999966,-84.2945957,-2.8229824,-0.0031377],\"covering\":{\"bbox\":{\"xmin\":[\"bbox\",\"xmin\"],\"ymin\":[\"bbox\",\"ymin\"],\"xmax\":[\"bbox\",\"xmax\"],\"ymax\":[\"bbox\",\"ymax\"]}}}}}",
#   "org.apache.spark.version": "3.5.4"
# }
# Geometry bounding box: [-179.9999966, -84.2945957, -2.8229824, -0.0031377]

# %%
con = duckdb.connect(database=':memory:')

for directory, files in sorted(files_by_dir.items()):
    sample_file = files[0]
    rel_dir = directory.relative_to(base_path)
    rel_label = '.' if str(rel_dir) == '.' else str(rel_dir)
    print(f"\n=== {rel_label} ===")
    print(f"Sample file: {sample_file.name}")
    schema_df = con.execute(
        "DESCRIBE SELECT * FROM read_parquet(?)", [str(sample_file)]
    ).fetchdf()
    display(schema_df)
    sample_rows_df = con.execute(
        "SELECT * FROM read_parquet(?) LIMIT 5", [str(sample_file)]
    ).fetchdf()
    display(sample_rows_df)
    print('Sources column sample:')
    for idx, value in sample_rows_df['sources'].items():
        print(f"Row {idx}: {value}")
# Out:
# === . ===
# Sample file: part-00000-c8f91a12-b93f-4285-9103-a7779634c4ce-c000.zstd.parquet
#                column_name                                        column_type  \
# 0                       id                                            VARCHAR
# 1                 geometry                                               BLOB
# 2                     bbox  STRUCT(xmin FLOAT, xmax FLOAT, ymin FLOAT, yma...
# 3                  version                                            INTEGER
# 4                  sources  STRUCT(property VARCHAR, dataset VARCHAR, reco...
# 5                    level                                            INTEGER
# 6                  subtype                                            VARCHAR
# 7                    class                                            VARCHAR
# 8                   height                                             DOUBLE
# 9                    names  STRUCT("primary" VARCHAR, common MAP(VARCHAR, ...
# 10               has_parts                                            BOOLEAN
# 11          is_underground                                            BOOLEAN
# 12              num_floors                                            INTEGER
# 13  num_floors_underground                                            INTEGER
# 14              min_height                                             DOUBLE
# 15               min_floor                                            INTEGER
# 16            facade_color                                            VARCHAR
# 17         facade_material                                            VARCHAR
# 18           roof_material                                            VARCHAR
# 19              roof_shape                                            VARCHAR
# 20          roof_direction                                             DOUBLE
# 21        roof_orientation                                            VARCHAR
# 22              roof_color                                            VARCHAR
# 23             roof_height                                             DOUBLE
# 24                   theme                                            VARCHAR
# 25                    type                                            VARCHAR
#
#    null   key default extra
# 0   YES  None    None  None
# 1   YES  None    None  None
# 2   YES  None    None  None
# 3   YES  None    None  None
# 4   YES  None    None  None
# 5   YES  None    None  None
# 6   YES  None    None  None
# 7   YES  None    None  None
# 8   YES  None    None  None
# 9   YES  None    None  None
# 10  YES  None    None  None
# 11  YES  None    None  None
# 12  YES  None    None  None
# 13  YES  None    None  None
# 14  YES  None    None  None
# 15  YES  None    None  None
# 16  YES  None    None  None
# 17  YES  None    None  None
# 18  YES  None    None  None
# 19  YES  None    None  None
# 20  YES  None    None  None
# 21  YES  None    None  None
# 22  YES  None    None  None
# 23  YES  None    None  None
# 24  YES  None    None  None
# 25  YES  None    None  None
#                                      id  \
# 0  68c64c74-0704-4030-8d79-bb30b20fd032
# 1  76c4a544-9ad3-4da0-be7d-22892dcbeb58
# 2  34adb9da-7e11-4cc9-b5a6-53ae5518188b
# 3  4fe39e6c-ca77-4b7a-84ac-95deb3f7eed4
# 4  0f5f2fa8-7810-4a97-87b4-6d3021bee377
#
#                                             geometry  \
# 0  [0, 0, 0, 0, 3, 0, 0, 0, 1, 0, 0, 0, 20, 192, ...
# 1  [0, 0, 0, 0, 3, 0, 0, 0, 1, 0, 0, 0, 6, 192, 1...
# 2  [0, 0, 0, 0, 3, 0, 0, 0, 1, 0, 0, 0, 5, 192, 9...
# 3  [0, 0, 0, 0, 3, 0, 0, 0, 1, 0, 0, 0, 5, 192, 9...
# 4  [0, 0, 0, 0, 3, 0, 0, 0, 1, 0, 0, 0, 5, 192, 9...
#
#                                                 bbox  version  \
# 0  {'xmin': -167.40013122558594, 'xmax': -167.399...        1
# 1  {'xmin': -179.96853637695312, 'xmax': -179.963...        1
# 2  {'xmin': -138.461181640625, 'xmax': -138.45275...        1
# 3  {'xmin': -136.80308532714844, 'xmax': -136.801...        1
# 4  {'xmin': -136.8033447265625, 'xmax': -136.8023...        1
#
#                                              sources  level    subtype class  \
# 0  [{'property': '', 'dataset': 'OpenStreetMap', ...   <NA>       None  None
# 1  [{'property': '', 'dataset': 'OpenStreetMap', ...   <NA>  religious  None
# 2  [{'property': '', 'dataset': 'OpenStreetMap', ...   <NA>       None  None
# 3  [{'property': '', 'dataset': 'OpenStreetMap', ...   <NA>       None  None
# 4  [{'property': '', 'dataset': 'OpenStreetMap', ...   <NA>       None  None
#
#    height                                              names  ...  \
# 0     NaN  {'primary': 'Marlene Weather Station', 'common...  ...
# 1     NaN  {'primary': 'St. Paul's Burgers', 'common': No...  ...
# 2     NaN                                               <NA>  ...
# 3     NaN                                               <NA>  ...
# 4     NaN                                               <NA>  ...
#
#    facade_color  facade_material  roof_material  roof_shape  roof_direction  \
# 0          None             None           None        None             NaN
# 1          None             None           None        None             NaN
# 2          None             None           None        None             NaN
# 3          None             None           None        None             NaN
# 4          None             None           None        None             NaN
#
#    roof_orientation roof_color roof_height      theme      type
# 0              None       None         NaN  buildings  building
# 1              None       None         NaN  buildings  building
# 2              None       None         NaN  buildings  building
# 3              None       None         NaN  buildings  building
# 4              None       None         NaN  buildings  building
#
# [5 rows x 26 columns]
# Sources column sample:
# Row 0: [{'property': '', 'dataset': 'OpenStreetMap', 'record_id': 'w325830447@3', 'update_time': '2015-02-01T01:46:06.000Z', 'confidence': None, 'between': None}]
# Row 1: [{'property': '', 'dataset': 'OpenStreetMap', 'record_id': 'w1417351285@1', 'update_time': '2025-07-25T18:07:43.000Z', 'confidence': None, 'between': None}]
# Row 2: [{'property': '', 'dataset': 'OpenStreetMap', 'record_id': 'w1380639824@1', 'update_time': '2025-04-24T10:41:55.000Z', 'confidence': None, 'between': None}]
# Row 3: [{'property': '', 'dataset': 'OpenStreetMap', 'record_id': 'w1250098696@1', 'update_time': '2024-02-14T01:23:09.000Z', 'confidence': None, 'between': None}]
# Row 4: [{'property': '', 'dataset': 'OpenStreetMap', 'record_id': 'w1250098698@1', 'update_time': '2024-02-14T01:23:09.000Z', 'confidence': None, 'between': None}]
